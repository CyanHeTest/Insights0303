# %%
from insightscontext import InsightsContext as ip
#from pyspark import SparkContext, SparkConf, HiveContext
from pyspark.sql import Row, SparkSession
from pyspark.sql.types import *
import pyspark.sql.functions as f
import pandas as pd
import requests
import os
ic = ip()

print("1. ###########  explore(),getStorageCredentials() Function Test ########################################")

ic.explore(type='wasb')

wasbSas = ic.getStorageCredentials(type = 'wasb')['sas']
print(ic.getStorageCredentials(type = 'wasb')['sas'])

spark = SparkSession\
.builder\
.appName("SparkJob Name - Project name: User Name")\
.config("fs.azure", "org.apache.hadoop.fs.azure.NativeAzureFileSystem")\
.config("fs.wasbs.impl","org.apache.hadoop.fs.azure.NativeAzureFileSystem")\
.config("fs.azure.sas.{0}.{1}.blob.core.windows.net".format(wasbSas['containerName'], wasbSas['storageAccountName']), wasbSas['sasToken'])\
.getOrCreate()


print("2. ###########  save_df_to_db Function Test ########################################")

#df = pd.DataFrame(ds_mssql,index=[0])
#ic.save_df_to_db('QA_table_write_df_NewFunction',df,ds_mssql)
#print("\n")
#print("Write into DB is Completed")

print("4. ###########  getApiKey() Function Test ########################################")
print('\n')
only_apiKey = ic.getApiKey()['apiKey']
print("API key is:  "+only_apiKey+"")

print("5. ###########  setEnvVariables(),getEnvVariables() Function Test ########################################")

envDict = dict(City = 'NewYork', Code = 'COVID-19', Status= 'Expanding', Mode= 'Pandemic')
ic.setEnvVariables(envDict)
print(ic.getEnvVariables())

print("6. ###########  getBaseUrl() Function Test ########################################")
baseurl = ic.getBaseUrl()+'/agent-service/api/git/listRepos?remoteOnly=true'
print(baseurl)

print("7. ###########  loadEnvVariables() Function Test ########################################")
ic.loadEnvVariables()
os.environ

print("8. ###########  os.environ #############################################################")
print(os.environ)

print("8. ###########  saveMSSQL, saveDremio() #############################################################")

ic.saveMSSQL(driver="Reg_24JUNE_ODBC Driver 17 for SQL Server",
            server="Reg_24JUNE_mssql-service",
            port=1433,
            database="Reg_24JUNE_C360UAMngmtTMTest5",
            username="Reg_24JUNE_cipwrite",
            password="Reg_24JUNE_PAAASSSWWWORDDD")
ic.saveDremio(driver="Reg_24JUNE_Dremio ODBC Driver 64-bit",
             server="Reg_24JUNE_52.150.38.92",
             port=31010,
             username="Reg_24JUNE_C360",
             password="Reg_24JUNE_PAAASSSWWWORDDD")
    
ds_mssql = ic.getMSSQL()
ds_dremio = ic.getDremio()

print("******* getMSSQL ************")
print(ds_mssql)
print("\n")
print("******* getDremio ************")
print(ds_dremio)

print("\n")

print(ds_mssql['connection_string'])
print(ds_dremio['connection_string'])


print("9. ###########  getMSSQL(),getDremio() Function Test ########################################")

ds_mssql = ic.getMSSQL()
ds_dremio = ic.getDremio()
print(ds_mssql)
print("\n")
print(ds_dremio)


#spark.stop()
# Out:
# 1. ###########  explore(),getStorageCredentials() Function Test ########################################
# {'containerName': 'qatenantjuly07t3705-23f29368659f498da60f0fa046a610a1', 'storageAccountName': 'wasbtestdev', 'sasToken': '?sv=2019-07-07&st=2020-06-18T05%3A13%3A05Z&se=2120-07-08T05%3A13%3A05Z&sr=c&sp=racwdl&sig=mRsIYSxQIPDGl7tdboOcMd0sC0WgEEqWofu5lUv32QE%3D', 'wasbUrl': 'wasbs://qatenantjuly07t3705-23f29368659f498da60f0fa046a610a1@wasbtestdev.blob.core.windows.net?sv=2019-07-07&st=2020-06-18T05%3A13%3A05Z&se=2120-07-08T05%3A13%3A05Z&sr=c&sp=racwdl&sig=mRsIYSxQIPDGl7tdboOcMd0sC0WgEEqWofu5lUv32QE%3D', 'wasbHttpsUrl': 'https://wasbtestdev.blob.core.windows.net/qatenantjuly07t3705-23f29368659f498da60f0fa046a610a1?sv=2019-07-07&st=2020-06-18T05%3A13%3A05Z&se=2120-07-08T05%3A13%3A05Z&sr=c&sp=racwdl&sig=mRsIYSxQIPDGl7tdboOcMd0sC0WgEEqWofu5lUv32QE%3D'}
# 2. ###########  save_df_to_db Function Test ########################################
# ...
